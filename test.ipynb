# %%
# %pip install streamlit
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.1 MB 1.9 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/9.1 MB 2.5 MB/s eta 0:00:04
#    -------- ------------------------------- 1.8/9.1 MB 2.7 MB/s eta 0:00:03
#    ------------ --------------------------- 2.9/9.1 MB 3.6 MB/s eta 0:00:02
#    ------------------ --------------------- 4.2/9.1 MB 4.1 MB/s eta 0:00:02
#    -------------------- ------------------- 4.7/9.1 MB 3.9 MB/s eta 0:00:02
#    ------------------------ --------------- 5.5/9.1 MB 3.7 MB/s eta 0:00:01
#    ------------------------ --------------- 5.5/9.1 MB 3.7 MB/s eta 0:00:01
#    -------------------------- ------------- 6.0/9.1 MB 3.3 MB/s eta 0:00:01
# ...

# %%
# %pip install -r requirements.txt
# Out:
# ...
#    ---------------------------------------- 0.0/996.9 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/996.9 kB ? eta -:--:--
#    ------------------------------- -------- 786.4/996.9 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 996.9/996.9 kB 2.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ------------------- -------------------- 1.0/2.2 MB 2.8 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.2 MB 2.9 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 2.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.6 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/7.6 MB 2.4 MB/s eta 0:00:03
# ...

# %%
# %run 0_👋_Home.py
# Out:
# 2025-01-29 17:48:06.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-29 17:48:06.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-29 17:48:06.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-29 17:48:06.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-29 17:48:06.947 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-29 17:48:06.947 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-29 17:48:06.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
